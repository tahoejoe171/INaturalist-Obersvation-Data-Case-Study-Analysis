# %%
import requests
requests.get("https://inaturalist-open-data.s3.amazonaws.com/photos/468332516/original.jpg")
# Out:
# <Response [200]>

# %% [markdown]
# ![](https://inaturalist-open-data.s3.amazonaws.com/photos/468332516/original.jpg)
