# %% [markdown]
# <h1>IDEAS</h1>
# <br>
# <li>find species with highest relative changes in observations, who are not among the most charismatic. See if they are invasive or not.</li>
# <li>Phenology: Visualize migratory trends in seabirds</li>
# <li>Obtaining elevations for random entries, 10000 of them and see what trends they have.</li>
